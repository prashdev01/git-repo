# %% [markdown]
# # Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# # matplotlib is a python library that is used to visualizing data into an graphical format , when we have a very large number of data and we wanted to know the specific behavior of that data it is almost imposible to know it by looking to all the data , because sometime the data comes with millons and billions of rows and columns , so for that purpose we use the matplotlib that represent the overall data in graphical foramt .
#
# # five plots that can be ploted using the pyplot module of matplotlib is as follows:
# # - Line Plot
# # - Scatter Plot
# # - Histogram
# # - bar Plot
# # - Pie Chart

# %% [markdown]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %%
# the scatter plot is a type of plote that represent by the dot on the graph 
# the dots are formed where the both the x and y axis interact with each other 
import matplotlib.pyplot as plt
import numpy as np 
np.random.seed(3) 
x = 3 + np.random.normal(0, 2, 50) 
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("this x axis :")
plt.ylabel("this y axis :")
plt.title("this is title of the scatter plot")
# Note: Also add title, xlabel, and ylabel to the plot.
# Out:
# Text(0.5, 1.0, 'this is title of the scatter plot')

# %% [markdown]
# # Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:
# # import numpy as np
# # For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# # For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# # For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# # For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
# The subplot() function in matplotlib is used to create multiple subplots within a single figure. This is useful when comparing multiple plots side-by-side.


import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2, 2, 1)
plt.plot(x1, y1)

plt.subplot(2, 2, 2)
plt.plot(x2, y2)

plt.subplot(2, 2, 3)
plt.plot(x3, y3)

plt.subplot(2, 2, 4)
plt.plot(x4, y4)

plt.show()

# %% [markdown]
# # Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# # import numpy as np
# # company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# # profit = np.array([3000, 8000, 1000, 10000])

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# # box1 = np.random.normal(100, 10, 200)
# # box2 = np.random.normal(90, 20, 200)

# %%
# A box plot, also known as a whisker plot, is a graphical representation of statistical data that displays the median, quartiles, and outliers of a set of data values. The box represents the interquartile range (IQR), which is the range between the first quartile (Q1) and the third quartile (Q3). The median is represented by a line within the box. The whiskers extend from the box to show the range of the data, with outliers plotted as individual points. Box plots are used to display the distribution of a dataset and to identify outliers

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data = [box1,box2]

plt.boxplot(data)
plt.show()
